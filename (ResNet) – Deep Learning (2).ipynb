# %%
# Import Keras modules and its important APIs
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# %%
# Setting Training Hyperparameters 
batch_size = 32  # original ResNet paper uses batch_size = 128 for training 
epochs = 200
data_augmentation = True
num_classes = 10

# Data Preprocessing  
subtract_pixel_mean = True
n = 3

# Select ResNet Version 
version = 1

# Computed depth of  
if version == 1: 
    depth = n * 6 + 2
elif version == 2: 
    depth = n * 9 + 2

# Model name, depth and version 
model_type = 'ResNet %dv%d' % (depth, version)

# Load the CIFAR-10 data. 
(x_train, y_train), (x_test, y_test) = cifar10.load_data() 

# Input image dimensions. 
input_shape = x_train.shape[1:] 

# Normalize data. 
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled 
if subtract_pixel_mean: 
    x_train_mean = np.mean(x_train, axis=0) 
    x_train -= x_train_mean 
    x_test -= x_train_mean 

# Print Training and Test Samples  
print('x_train shape:', x_train.shape) 
print(x_train.shape[0], 'train samples') 
print(x_test.shape[0], 'test samples') 
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# Convert class vectors to binary class matrices. 
y_train = keras.utils.to_categorical(y_train, num_classes) 
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
# Setting LR for different number of Epochs 
def lr_schedule(epoch): 
    lr = 1e-3
    if epoch > 180: 
        lr *= 0.5e-3
    elif epoch > 160: 
        lr *= 1e-3
    elif epoch > 120: 
        lr *= 1e-2
    elif epoch > 80: 
        lr *= 1e-1
    print('Learning rate: ', lr) 
    return lr

# %%
# Basic ResNet Building Block 
def resnet_layer(inputs, 
                 num_filters=16, 
                 kernel_size=3, 
                 strides=1, 
                 activation='relu', 
                 batch_normalization=True, 
                 conv_first=True):
    conv = Conv2D(num_filters, 
                  kernel_size=kernel_size, 
                  strides=strides, 
                  padding='same', 
                  kernel_initializer='he_normal', 
                  kernel_regularizer=l2(1e-4))

    x = inputs 
    if conv_first: 
        x = conv(x) 
        if batch_normalization: 
            x = BatchNormalization()(x) 
        if activation is not None: 
            x = Activation(activation)(x) 
    else: 
        if batch_normalization: 
            x = BatchNormalization()(x) 
        if activation is not None: 
            x = Activation(activation)(x) 
        x = conv(x) 
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10): 
    if (depth - 2) % 6 != 0: 
        raise ValueError('depth should be 6n + 2 (eg 20, 32, 44 in [a])') 
    # Start model definition. 
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6) 

    inputs = Input(shape=input_shape) 
    x = resnet_layer(inputs=inputs) 
    # Instantiate the stack of residual units 
    for stack in range(3): 
        for res_block in range(num_res_blocks): 
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack 
                strides = 2  # downsample 
            y = resnet_layer(inputs=x, 
                             num_filters=num_filters, 
                             strides=strides) 
            y = resnet_layer(inputs=y, 
                             num_filters=num_filters, 
                             activation=None) 
            if stack > 0 and res_block == 0:  # first layer but not first stack 
                # linear projection residual shortcut connection to match 
                # changed dims 
                x = resnet_layer(inputs=x, 
                                 num_filters=num_filters, 
                                 kernel_size=1, 
                                 strides=strides, 
                                 activation=None, 
                                 batch_normalization=False) 
            x = keras.layers.add([x, y]) 
            x = Activation('relu')(x) 
        num_filters *= 2

    # Add classifier on top. 
    # v1 does not use BN after last shortcut connection-ReLU 
    x = AveragePooling2D(pool_size=8)(x) 
    y = Flatten()(x) 
    outputs = Dense(num_classes, 
                    activation='softmax', 
                    kernel_initializer='he_normal')(y) 

    # Instantiate model. 
    model = Model(inputs=inputs, outputs=outputs) 
    return model

# %%
# ResNet V2 architecture 
def resnet_v2(input_shape, depth, num_classes=10): 
    if (depth - 2) % 9 != 0: 
        raise ValueError('depth should be 9n + 2 (eg 56 or 110 in [b])') 
    # Start model definition. 
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9) 

    inputs = Input(shape=input_shape) 
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths 
    x = resnet_layer(inputs=inputs, 
                     num_filters=num_filters_in, 
                     conv_first=True) 

    # Instantiate the stack of residual units 
    for stage in range(3): 
        for res_block in range(num_res_blocks): 
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0: 
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage 
                    activation = None
                    batch_normalization = False
            else: 
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage 
                    strides = 2    # downsample 

            # bottleneck residual unit 
            y = resnet_layer(inputs=x, 
                             num_filters=num_filters_in, 
                             kernel_size=1, 
                             strides=strides, 
                             activation=activation, 
                             batch_normalization=batch_normalization, 
                             conv_first=False) 
            y = resnet_layer(inputs=y, 
                             num_filters=num_filters_in, 
                             conv_first=False) 
            y = resnet_layer(inputs=y, 
                             num_filters=num_filters_out, 
                             kernel_size=1, 
                             conv_first=False) 
            if res_block == 0: 
                # linear projection residual shortcut connection to match 
                # changed dims 
                x = resnet_layer(inputs=x, 
                                 num_filters=num_filters_out, 
                                 kernel_size=1, 
                                 strides=strides, 
                                 activation=None, 
                                 batch_normalization=False) 
            x = keras.layers.add([x, y]) 

        num_filters_in = num_filters_out 

    # Add classifier on top. 
    # v2 has BN-ReLU before Pooling 
    x = BatchNormalization()(x) 
    x = Activation('relu')(x) 
    x = AveragePooling2D(pool_size=8)(x) 
    y = Flatten()(x) 
    outputs = Dense(num_classes, 
                    activation='softmax', 
                    kernel_initializer='he_normal')(y) 

    # Instantiate model. 
    model = Model(inputs=inputs, outputs=outputs) 
    return model

# %%
# Main function  
if version == 2: 
    model = resnet_v2(input_shape=input_shape, depth=depth) 
else: 
    model = resnet_v1(input_shape=input_shape, depth=depth) 

model.compile(loss='categorical_crossentropy', 
              optimizer=Adam(learning_rate=lr_schedule(0)), 
              metrics=['accuracy']) 
model.summary() 
print(model_type) 

# Prepare model saving directory. 
save_dir = os.path.join(os.getcwd(), 'saved_models') 
model_name = 'cifar10_%s_model.{epoch:03d}.keras' % model_type 
if not os.path.isdir(save_dir): 
    os.makedirs(save_dir) 
filepath = os.path.join(save_dir, model_name) 

# Prepare callbacks for model saving and for learning rate adjustment. 
checkpoint = ModelCheckpoint(filepath=filepath, 
                             monitor='val_accuracy', 
                             verbose=1, 
                             save_best_only=True) 

lr_scheduler = LearningRateScheduler(lr_schedule) 

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), 
                               cooldown=0, 
                               patience=5, 
                               min_lr=0.5e-6) 

callbacks = [checkpoint, lr_reducer, lr_scheduler]
# Out:
# Learning rate:  0.001
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 32, 32, 3)         │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d (Conv2D)               │ (None, 32, 32, 16)        │             448 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 32, 32, 16)        │              64 │ conv2d[0][0]               │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation (Activation)       │ (None, 32, 32, 16)        │               0 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_1 (Conv2D)             │ (None, 32, 32, 16)        │           2,320 │ activation[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 32, 32, 16)        │              64 │ conv2d_1[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_1 (Activation)     │ (None, 32, 32, 16)        │               0 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_2 (Conv2D)             │ (None, 32, 32, 16)        │           2,320 │ activation_1[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 32, 32, 16)        │              64 │ conv2d_2[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 32, 32, 16)        │               0 │ activation[0][0],          │
# │                               │                           │                 │ batch_normalization_2[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_2 (Activation)     │ (None, 32, 32, 16)        │               0 │ add[0][0]                  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_3 (Conv2D)             │ (None, 32, 32, 16)        │           2,320 │ activation_2[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_3         │ (None, 32, 32, 16)        │              64 │ conv2d_3[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_3 (Activation)     │ (None, 32, 32, 16)        │               0 │ batch_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_4 (Conv2D)             │ (None, 32, 32, 16)        │           2,320 │ activation_3[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_4         │ (None, 32, 32, 16)        │              64 │ conv2d_4[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 32, 32, 16)        │               0 │ activation_2[0][0],        │
# │                               │                           │                 │ batch_normalization_4[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_4 (Activation)     │ (None, 32, 32, 16)        │               0 │ add_1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_5 (Conv2D)             │ (None, 32, 32, 16)        │           2,320 │ activation_4[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_5         │ (None, 32, 32, 16)        │              64 │ conv2d_5[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_5 (Activation)     │ (None, 32, 32, 16)        │               0 │ batch_normalization_5[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_6 (Conv2D)             │ (None, 32, 32, 16)        │           2,320 │ activation_5[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_6         │ (None, 32, 32, 16)        │              64 │ conv2d_6[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 32, 32, 16)        │               0 │ activation_4[0][0],        │
# │                               │                           │                 │ batch_normalization_6[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_6 (Activation)     │ (None, 32, 32, 16)        │               0 │ add_2[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_7 (Conv2D)             │ (None, 16, 16, 32)        │           4,640 │ activation_6[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_7         │ (None, 16, 16, 32)        │             128 │ conv2d_7[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_7 (Activation)     │ (None, 16, 16, 32)        │               0 │ batch_normalization_7[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_8 (Conv2D)             │ (None, 16, 16, 32)        │           9,248 │ activation_7[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_9 (Conv2D)             │ (None, 16, 16, 32)        │             544 │ activation_6[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_8         │ (None, 16, 16, 32)        │             128 │ conv2d_8[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 16, 16, 32)        │               0 │ conv2d_9[0][0],            │
# │                               │                           │                 │ batch_normalization_8[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_8 (Activation)     │ (None, 16, 16, 32)        │               0 │ add_3[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_10 (Conv2D)            │ (None, 16, 16, 32)        │           9,248 │ activation_8[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_9         │ (None, 16, 16, 32)        │             128 │ conv2d_10[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_9 (Activation)     │ (None, 16, 16, 32)        │               0 │ batch_normalization_9[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_11 (Conv2D)            │ (None, 16, 16, 32)        │           9,248 │ activation_9[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_10        │ (None, 16, 16, 32)        │             128 │ conv2d_11[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_4 (Add)                   │ (None, 16, 16, 32)        │               0 │ activation_8[0][0],        │
# │                               │                           │                 │ batch_normalization_10[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_10 (Activation)    │ (None, 16, 16, 32)        │               0 │ add_4[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_12 (Conv2D)            │ (None, 16, 16, 32)        │           9,248 │ activation_10[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_11        │ (None, 16, 16, 32)        │             128 │ conv2d_12[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_11 (Activation)    │ (None, 16, 16, 32)        │               0 │ batch_normalization_11[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_13 (Conv2D)            │ (None, 16, 16, 32)        │           9,248 │ activation_11[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_12        │ (None, 16, 16, 32)        │             128 │ conv2d_13[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_5 (Add)                   │ (None, 16, 16, 32)        │               0 │ activation_10[0][0],       │
# │                               │                           │                 │ batch_normalization_12[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_12 (Activation)    │ (None, 16, 16, 32)        │               0 │ add_5[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_14 (Conv2D)            │ (None, 8, 8, 64)          │          18,496 │ activation_12[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_13        │ (None, 8, 8, 64)          │             256 │ conv2d_14[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_13 (Activation)    │ (None, 8, 8, 64)          │               0 │ batch_normalization_13[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_15 (Conv2D)            │ (None, 8, 8, 64)          │          36,928 │ activation_13[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_16 (Conv2D)            │ (None, 8, 8, 64)          │           2,112 │ activation_12[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_14        │ (None, 8, 8, 64)          │             256 │ conv2d_15[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_6 (Add)                   │ (None, 8, 8, 64)          │               0 │ conv2d_16[0][0],           │
# │                               │                           │                 │ batch_normalization_14[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_14 (Activation)    │ (None, 8, 8, 64)          │               0 │ add_6[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_17 (Conv2D)            │ (None, 8, 8, 64)          │          36,928 │ activation_14[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_15        │ (None, 8, 8, 64)          │             256 │ conv2d_17[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_15 (Activation)    │ (None, 8, 8, 64)          │               0 │ batch_normalization_15[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_18 (Conv2D)            │ (None, 8, 8, 64)          │          36,928 │ activation_15[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_16        │ (None, 8, 8, 64)          │             256 │ conv2d_18[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_7 (Add)                   │ (None, 8, 8, 64)          │               0 │ activation_14[0][0],       │
# │                               │                           │                 │ batch_normalization_16[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_16 (Activation)    │ (None, 8, 8, 64)          │               0 │ add_7[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_19 (Conv2D)            │ (None, 8, 8, 64)          │          36,928 │ activation_16[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_17        │ (None, 8, 8, 64)          │             256 │ conv2d_19[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_17 (Activation)    │ (None, 8, 8, 64)          │               0 │ batch_normalization_17[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_20 (Conv2D)            │ (None, 8, 8, 64)          │          36,928 │ activation_17[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_18        │ (None, 8, 8, 64)          │             256 │ conv2d_20[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_8 (Add)                   │ (None, 8, 8, 64)          │               0 │ activation_16[0][0],       │
# │                               │                           │                 │ batch_normalization_18[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_18 (Activation)    │ (None, 8, 8, 64)          │               0 │ add_8[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ average_pooling2d             │ (None, 1, 1, 64)          │               0 │ activation_18[0][0]        │
# │ (AveragePooling2D)            │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 64)                │               0 │ average_pooling2d[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 10)                │             650 │ flatten[0][0]              │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 274,442 (1.05 MB)
#  Trainable params: 273,066 (1.04 MB)
#  Non-trainable params: 1,376 (5.38 KB)
# ResNet 20v1

# %%
# Run training, with or without data augmentation. 
if not data_augmentation: 
    print('Not using data augmentation.') 
    model.fit(x_train, y_train, 
              batch_size=batch_size, 
              epochs=epochs, 
              validation_data=(x_test, y_test), 
              shuffle=True, 
              callbacks=callbacks) 
else: 
    print('Using real-time data augmentation.') 
    # This will do preprocessing and realtime data augmentation: 
    datagen = ImageDataGenerator( 
        # set input mean to 0 over the dataset 
        featurewise_center=False, 
        # set each sample mean to 0 
        samplewise_center=False, 
        # divide inputs by std of dataset 
        featurewise_std_normalization=False, 
        # divide each input by its std 
        samplewise_std_normalization=False, 
        # apply ZCA whitening 
        zca_whitening=False, 
        # epsilon for ZCA whitening 
        zca_epsilon=1e-06, 
        # randomly rotate images in the range (deg 0 to 180) 
        rotation_range=0, 
        # randomly shift images horizontally 
        width_shift_range=0.1, 
        # randomly shift images vertically 
        height_shift_range=0.1, 
        # set range for random shear 
        shear_range=0., 
        # set range for random zoom 
        zoom_range=0., 
        # set range for random channel shifts 
        channel_shift_range=0., 
        # set mode for filling points outside the input boundaries 
        fill_mode='nearest', 
        # value used for fill_mode="constant" 
        cval=0., 
        # randomly flip images 
        horizontal_flip=True, 
        # randomly flip images 
        vertical_flip=False, 
        # set rescaling factor (applied before any other transformation) 
        rescale=None, 
        # set function that will be applied on each input 
        preprocessing_function=None, 
        # image data format, either "channels_first" or "channels_last" 
        data_format=None, 
        # fraction of images reserved for validation (strictly between 0 and 1) 
        validation_split=0.0) 

    # Compute quantities required for featurewise normalization 
    # (std, mean, and principal components if ZCA whitening is applied). 
    datagen.fit(x_train) 

    # Fit the model on the batches generated by datagen.flow(). 
    model.fit(datagen.flow(x_train, y_train, batch_size=batch_size), 
              validation_data=(x_test, y_test), 
              epochs=epochs, 
              verbose=1, 
              callbacks=callbacks) 

# Score trained model. 
scores = model.evaluate(x_test, y_test, verbose=1) 
print('Test loss:', scores[0]) 
print('Test accuracy:', scores[1])
# Out:
# Using real-time data augmentation.
# Learning rate:  0.001
# Epoch 1/200
# C:\Users\OFFICE\anaconda\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4099 - loss: 1.8238
# Epoch 1: val_accuracy improved from -inf to 0.49620, saving model to C:\Users\OFFICE\Data_visualization\Residual Networks (ResNet) – Deep Learning\saved_models\cifar10_ResNet 20v1_model.001.keras
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 155s 92ms/step - accuracy: 0.4099 - loss: 1.8236 - val_accuracy: 0.4962 - val_loss: 1.5945 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 2/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6208 - loss: 1.2223
# Epoch 2: val_accuracy improved from 0.49620 to 0.57580, saving model to C:\Users\OFFICE\Data_visualization\Residual Networks (ResNet) – Deep Learning\saved_models\cifar10_ResNet 20v1_model.002.keras
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 152s 97ms/step - accuracy: 0.6208 - loss: 1.2223 - val_accuracy: 0.5758 - val_loss: 1.5374 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 3/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.6886 - loss: 1.0437
# Epoch 3: val_accuracy improved from 0.57580 to 0.63130, saving model to C:\Users\OFFICE\Data_visualization\Residual Networks (ResNet) – Deep Learning\saved_models\cifar10_ResNet 20v1_model.003.keras
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 141s 90ms/step - accuracy: 0.6886 - loss: 1.0437 - val_accuracy: 0.6313 - val_loss: 1.2970 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 4/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7327 - loss: 0.9386
# Epoch 4: val_accuracy improved from 0.63130 to 0.71430, saving model to C:\Users\OFFICE\Data_visualization\Residual Networks (ResNet) – Deep Learning\saved_models\cifar10_ResNet 20v1_model.004.keras
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 143s 92ms/step - accuracy: 0.7327 - loss: 0.9386 - val_accuracy: 0.7143 - val_loss: 1.0170 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 5/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7554 - loss: 0.8760
# Epoch 5: val_accuracy did not improve from 0.71430
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 138s 88ms/step - accuracy: 0.7554 - loss: 0.8760 - val_accuracy: 0.7112 - val_loss: 1.0453 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 6/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7712 - loss: 0.8253
# Epoch 6: val_accuracy improved from 0.71430 to 0.73730, saving model to C:\Users\OFFICE\Data_visualization\Residual Networks (ResNet) – Deep Learning\saved_models\cifar10_ResNet 20v1_model.006.keras
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 136s 87ms/step - accuracy: 0.7712 - loss: 0.8253 - val_accuracy: 0.7373 - val_loss: 0.9556 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 7/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7889 - loss: 0.7862
# Epoch 7: val_accuracy improved from 0.73730 to 0.79420, saving model to C:\Users\OFFICE\Data_visualization\Residual Networks (ResNet) – Deep Learning\saved_models\cifar10_ResNet 20v1_model.007.keras
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 139s 89ms/step - accuracy: 0.7889 - loss: 0.7862 - val_accuracy: 0.7942 - val_loss: 0.7912 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 8/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8015 - loss: 0.7529
# Epoch 8: val_accuracy did not improve from 0.79420
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 143s 91ms/step - accuracy: 0.8015 - loss: 0.7529 - val_accuracy: 0.7118 - val_loss: 1.0702 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 9/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8102 - loss: 0.7263
# Epoch 9: val_accuracy did not improve from 0.79420
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 146s 94ms/step - accuracy: 0.8102 - loss: 0.7263 - val_accuracy: 0.7758 - val_loss: 0.8548 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 10/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8155 - loss: 0.7130
# Epoch 10: val_accuracy did not improve from 0.79420
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 150s 96ms/step - accuracy: 0.8155 - loss: 0.7130 - val_accuracy: 0.7826 - val_loss: 0.8405 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 11/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8213 - loss: 0.6943
# Epoch 11: val_accuracy did not improve from 0.79420
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 149s 95ms/step - accuracy: 0.8213 - loss: 0.6943 - val_accuracy: 0.7252 - val_loss: 1.0370 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 12/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8297 - loss: 0.6810
# Epoch 12: val_accuracy did not improve from 0.79420
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 149s 95ms/step - accuracy: 0.8297 - loss: 0.6810 - val_accuracy: 0.7809 - val_loss: 0.8287 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 13/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8367 - loss: 0.6663
# Epoch 13: val_accuracy improved from 0.79420 to 0.79750, saving model to C:\Users\OFFICE\Data_visualization\Residual Networks (ResNet) – Deep Learning\saved_models\cifar10_ResNet 20v1_model.013.keras
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 148s 94ms/step - accuracy: 0.8367 - loss: 0.6663 - val_accuracy: 0.7975 - val_loss: 0.7980 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 14/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8409 - loss: 0.6542
# Epoch 14: val_accuracy improved from 0.79750 to 0.81720, saving model to C:\Users\OFFICE\Data_visualization\Residual Networks (ResNet) – Deep Learning\saved_models\cifar10_ResNet 20v1_model.014.keras
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 151s 97ms/step - accuracy: 0.8409 - loss: 0.6542 - val_accuracy: 0.8172 - val_loss: 0.7303 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 15/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8439 - loss: 0.6457
# Epoch 15: val_accuracy did not improve from 0.81720
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 149s 95ms/step - accuracy: 0.8439 - loss: 0.6457 - val_accuracy: 0.8156 - val_loss: 0.7574 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 16/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8475 - loss: 0.6315
# Epoch 16: val_accuracy did not improve from 0.81720
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 150s 96ms/step - accuracy: 0.8475 - loss: 0.6315 - val_accuracy: 0.8020 - val_loss: 0.7902 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 17/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8495 - loss: 0.6254
# Epoch 17: val_accuracy improved from 0.81720 to 0.84000, saving model to C:\Users\OFFICE\Data_visualization\Residual Networks (ResNet) – Deep Learning\saved_models\cifar10_ResNet 20v1_model.017.keras
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 150s 96ms/step - accuracy: 0.8495 - loss: 0.6254 - val_accuracy: 0.8400 - val_loss: 0.6721 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 18/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8526 - loss: 0.6228
# Epoch 18: val_accuracy did not improve from 0.84000
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 150s 96ms/step - accuracy: 0.8526 - loss: 0.6228 - val_accuracy: 0.8334 - val_loss: 0.6829 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 19/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8507 - loss: 0.6222
# Epoch 19: val_accuracy did not improve from 0.84000
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 151s 97ms/step - accuracy: 0.8507 - loss: 0.6222 - val_accuracy: 0.7993 - val_loss: 0.8391 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 20/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8565 - loss: 0.6039
# Epoch 20: val_accuracy did not improve from 0.84000
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 152s 97ms/step - accuracy: 0.8565 - loss: 0.6039 - val_accuracy: 0.8184 - val_loss: 0.7463 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 21/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8599 - loss: 0.5987
# Epoch 21: val_accuracy did not improve from 0.84000
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 153s 98ms/step - accuracy: 0.8599 - loss: 0.5987 - val_accuracy: 0.7934 - val_loss: 0.8617 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 22/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8598 - loss: 0.6011
# Epoch 22: val_accuracy did not improve from 0.84000
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 153s 98ms/step - accuracy: 0.8598 - loss: 0.6011 - val_accuracy: 0.7457 - val_loss: 1.0201 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 23/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8660 - loss: 0.5869
# Epoch 23: val_accuracy did not improve from 0.84000
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 154s 98ms/step - accuracy: 0.8660 - loss: 0.5869 - val_accuracy: 0.8146 - val_loss: 0.7513 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 24/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8700 - loss: 0.5747
# Epoch 24: val_accuracy did not improve from 0.84000
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 154s 99ms/step - accuracy: 0.8700 - loss: 0.5748 - val_accuracy: 0.8271 - val_loss: 0.7369 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 25/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8696 - loss: 0.5758
# Epoch 25: val_accuracy did not improve from 0.84000
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 155s 99ms/step - accuracy: 0.8696 - loss: 0.5758 - val_accuracy: 0.8195 - val_loss: 0.7569 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 26/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8687 - loss: 0.5739
# Epoch 26: val_accuracy did not improve from 0.84000
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 155s 99ms/step - accuracy: 0.8687 - loss: 0.5739 - val_accuracy: 0.8125 - val_loss: 0.7904 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 27/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8750 - loss: 0.5638
# Epoch 27: val_accuracy did not improve from 0.84000
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 157s 100ms/step - accuracy: 0.8750 - loss: 0.5638 - val_accuracy: 0.8376 - val_loss: 0.6927 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 28/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8771 - loss: 0.5611
# Epoch 28: val_accuracy did not improve from 0.84000
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 158s 101ms/step - accuracy: 0.8771 - loss: 0.5611 - val_accuracy: 0.8166 - val_loss: 0.7626 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 29/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8763 - loss: 0.5606
# Epoch 29: val_accuracy improved from 0.84000 to 0.85290, saving model to C:\Users\OFFICE\Data_visualization\Residual Networks (ResNet) – Deep Learning\saved_models\cifar10_ResNet 20v1_model.029.keras
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 158s 101ms/step - accuracy: 0.8763 - loss: 0.5606 - val_accuracy: 0.8529 - val_loss: 0.6559 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 30/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8777 - loss: 0.5576
# Epoch 30: val_accuracy did not improve from 0.85290
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 159s 101ms/step - accuracy: 0.8777 - loss: 0.5576 - val_accuracy: 0.8286 - val_loss: 0.7420 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 31/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8755 - loss: 0.5659
# Epoch 31: val_accuracy did not improve from 0.85290
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 159s 102ms/step - accuracy: 0.8755 - loss: 0.5659 - val_accuracy: 0.7616 - val_loss: 0.9675 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 32/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8785 - loss: 0.5545
# Epoch 32: val_accuracy did not improve from 0.85290
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 160s 103ms/step - accuracy: 0.8785 - loss: 0.5545 - val_accuracy: 0.8343 - val_loss: 0.6907 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 33/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8803 - loss: 0.5434
# Epoch 33: val_accuracy did not improve from 0.85290
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 161s 103ms/step - accuracy: 0.8803 - loss: 0.5434 - val_accuracy: 0.8323 - val_loss: 0.7042 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 34/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8847 - loss: 0.5352
# Epoch 35: val_accuracy did not improve from 0.85290
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 150s 96ms/step - accuracy: 0.8847 - loss: 0.5352 - val_accuracy: 0.8092 - val_loss: 0.8283 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 36/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8827 - loss: 0.5459
# Epoch 36: val_accuracy did not improve from 0.85290
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 157s 100ms/step - accuracy: 0.8827 - loss: 0.5459 - val_accuracy: 0.8174 - val_loss: 0.7785 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 37/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8852 - loss: 0.5369
# Epoch 37: val_accuracy did not improve from 0.85290
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 154s 99ms/step - accuracy: 0.8852 - loss: 0.5369 - val_accuracy: 0.8147 - val_loss: 0.7855 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 38/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8854 - loss: 0.5295
# Epoch 38: val_accuracy did not improve from 0.85290
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 155s 99ms/step - accuracy: 0.8854 - loss: 0.5295 - val_accuracy: 0.8472 - val_loss: 0.6624 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 39/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8863 - loss: 0.5362
# Epoch 39: val_accuracy improved from 0.85290 to 0.85740, saving model to C:\Users\OFFICE\Data_visualization\Residual Networks (ResNet) – Deep Learning\saved_models\cifar10_ResNet 20v1_model.039.keras
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 181s 116ms/step - accuracy: 0.8862 - loss: 0.5362 - val_accuracy: 0.8574 - val_loss: 0.6341 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 40/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8872 - loss: 0.5296
# Epoch 40: val_accuracy did not improve from 0.85740
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 176s 113ms/step - accuracy: 0.8872 - loss: 0.5296 - val_accuracy: 0.7866 - val_loss: 0.8972 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 41/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.8896 - loss: 0.5254
# Epoch 41: val_accuracy did not improve from 0.85740
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 173s 110ms/step - accuracy: 0.8896 - loss: 0.5254 - val_accuracy: 0.8096 - val_loss: 0.8238 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 42/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8890 - loss: 0.5249
# Epoch 42: val_accuracy did not improve from 0.85740
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 180s 115ms/step - accuracy: 0.8890 - loss: 0.5249 - val_accuracy: 0.8268 - val_loss: 0.7361 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 43/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.8878 - loss: 0.5249
# Epoch 43: val_accuracy did not improve from 0.85740
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 172s 110ms/step - accuracy: 0.8878 - loss: 0.5249 - val_accuracy: 0.8222 - val_loss: 0.7761 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 44/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8907 - loss: 0.5215
# Epoch 44: val_accuracy did not improve from 0.85740
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 155s 99ms/step - accuracy: 0.8907 - loss: 0.5215 - val_accuracy: 0.8233 - val_loss: 0.7717 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 45/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8876 - loss: 0.5283
# Epoch 45: val_accuracy did not improve from 0.85740
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 158s 101ms/step - accuracy: 0.8876 - loss: 0.5283 - val_accuracy: 0.8506 - val_loss: 0.6572 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 46/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8887 - loss: 0.5229
# Epoch 46: val_accuracy did not improve from 0.85740
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 177s 113ms/step - accuracy: 0.8887 - loss: 0.5229 - val_accuracy: 0.8492 - val_loss: 0.6748 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 47/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.8935 - loss: 0.5161
# Epoch 47: val_accuracy did not improve from 0.85740
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 170s 109ms/step - accuracy: 0.8935 - loss: 0.5161 - val_accuracy: 0.8380 - val_loss: 0.6986 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 48/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8919 - loss: 0.5146
# Epoch 48: val_accuracy did not improve from 0.85740
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 183s 117ms/step - accuracy: 0.8919 - loss: 0.5146 - val_accuracy: 0.8369 - val_loss: 0.7007 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 49/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8911 - loss: 0.5162
# Epoch 49: val_accuracy did not improve from 0.85740
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 191s 122ms/step - accuracy: 0.8911 - loss: 0.5162 - val_accuracy: 0.8535 - val_loss: 0.6390 - learning_rate: 3.1623e-04
# Learning rate:  0.001
# Epoch 50/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8941 - loss: 0.5117
# Epoch 50: val_accuracy did not improve from 0.85740
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 187s 120ms/step - accuracy: 0.8941 - loss: 0.5117 - val_accuracy: 0.8570 - val_loss: 0.6352 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 51/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.8941 - loss: 0.5122
# Epoch 51: val_accuracy did not improve from 0.85740
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 174s 111ms/step - accuracy: 0.8941 - loss: 0.5122 - val_accuracy: 0.8022 - val_loss: 0.8577 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 52/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8945 - loss: 0.5130
# Epoch 52: val_accuracy did not improve from 0.85740
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 185s 118ms/step - accuracy: 0.8945 - loss: 0.5130 - val_accuracy: 0.8221 - val_loss: 0.7703 - learning_rate: 0.0010
# Learning rate:  0.001
# Epoch 53/200
#  294/1563 ━━━━━━━━━━━━━━━━━━━━ 2:27 117ms/step - accuracy: 0.8936 - loss: 0.4983
